# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.metrics import mean_squared_error
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_absolute_error

# %%
# Importing the dataset
dataset = pd.read_csv('C:\\Users\\Fabiel Fernando\\Desktop\\PROVA\\regressao_Q7.csv')

# %%
dataset.head()
# Out:
#          x0        x1        x2        x3        x4        x5        x6  \
# 0  0.591690  0.591690  1.172172 -0.983677 -1.723861 -1.872732  1.070023
# 1  0.617718  0.617718  1.066885 -0.994460 -1.660279 -2.006098  0.800897
# 2 -0.091250 -0.091250  0.460780 -2.076651 -2.903264 -3.110400 -0.361113
# 3 -0.264834 -0.264834  1.061765 -0.539020 -0.972137 -1.102153  1.198790
# 4  0.308724  0.308724  0.793572 -1.162892 -2.315907 -2.436588  0.038154
#
#          x7        x8        x9     ...           x11       x12       x13  \
# 0 -0.623034  1.705102  2.643913     ...      2.643913 -0.623034  2.643913
# 1 -0.150230  1.601513  2.227607     ...      2.227607 -0.150230  2.227607
# 2 -2.029327  0.320967  1.514848     ...      1.514848 -2.029327  1.514848
# 3 -0.534910  2.272581  2.748045     ...      2.748045 -0.534910  2.748045
# 4 -1.335393  1.586416  1.898164     ...      1.898164 -1.335393  1.898164
#
#         x14       x15       x16       x17       x18       x19      target
# ...

# %%
X = dataset.iloc[:, 0:20].values
#pd.DataFrame(X).head()
y = dataset.iloc[:, 20:21].values
#pd.DataFrame(y).head()

# %%
from sklearn.model_selection import StratifiedKFold, KFold, LeaveOneOut
cv_kfold =KFold(n_splits=10, shuffle=False, random_state=42)
cv_loo = LeaveOneOut()

# %%
parameters = {
             }

# %%
dtree = DecisionTreeRegressor(random_state = 42,criterion = "mse")
cv_dtree = GridSearchCV(estimator = dtree, 
                          param_grid = parameters,
                          scoring= 'neg_mean_absolute_error',
                          return_train_score=True,
                          cv=cv_kfold)

# %%
gridcv_dtree = cv_dtree.fit(X, y)

# %%
modelo_dtree = gridcv_dtree.best_estimator_

# %%
y_pred_train =cv_dtree.predict(X)

# %%
# MAE conjunto de treino
mae = np.sqrt(mean_absolute_error(y, y_pred_train))
print("MAE: {}".format(mae))
# Out:
# MAE: 0.0

# %%
result = pd.DataFrame(gridcv_dtree.cv_results_)
result
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time params  \
# 0       0.046873      0.009882              0.0             0.0     {}
#
#    split0_test_score  split1_test_score  split2_test_score  split3_test_score  \
# 0         -52.530348         -54.950031         -54.322938         -47.020525
#
#    split4_test_score       ...         split2_train_score  split3_train_score  \
# 0         -51.005329       ...                       -0.0                -0.0
#
#    split4_train_score  split5_train_score  split6_train_score  \
# 0                -0.0       -3.448832e-07                -0.0
#
#    split7_train_score  split8_train_score  split9_train_score  \
# 0       -3.448832e-07                -0.0                -0.0
#
#    mean_train_score  std_train_score
# 0     -6.897663e-08     1.379533e-07
#
# [1 rows x 30 columns]
