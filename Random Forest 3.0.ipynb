# %% [markdown]
# # Random Forest

# %% [markdown]
# #### Importando bibliotecas

# %%
# %matplotlib inline

import time
import random
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.model_selection import KFold, cross_val_score
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier 
from sklearn.metrics  import   accuracy_score 
from sklearn import datasets
from sklearn import metrics
from sklearn.model_selection import LeaveOneOut
from sklearn.model_selection import KFold

plt.style.use('ggplot')
pd.set_option('display.max_columns', 500)

# %%
def results_holdout(clf, X_train, y_train, X_test, y_test):
    
    classifier = clf.fit(X_train, np.ravel(y_train))
    metrics = [f1_score, precision_score, recall_score, accuracy_score, roc_auc_score]
    
    pred_train = classifier.predict(X_train)
    pred_test = classifier.predict(X_test)

    prob_train = classifier.predict_proba(X_train)
    prob_train_true = pd.DataFrame(prob_train).iloc[:,1] #prob de ser 1
    prob_test = classifier.predict_proba(X_test)
    prob_test_true = pd.DataFrame(prob_test).iloc[:,1]
    
    results = pd.DataFrame()
    
    for m in metrics:
        if m == roc_auc_score:
                result_train = m(y_train, prob_train_true)
                result_test = m(y_test, prob_test_true)
        else:        
            result_train = m(y_train, pred_train)
            result_test = m(y_test, pred_test)
        
        dict_res = {'Treino': [result_train], 'Teste': [result_test]}
        res_aux = pd.DataFrame(dict_res, index = [str(m.__name__)])
        
        results = pd.concat([results, res_aux], axis = 0)
    
    
    train_res = pd.concat([y_train, pd.DataFrame(prob_train).iloc[:,1]], axis = 1)
    test_res = pd.concat([y_test, pd.DataFrame(prob_test).iloc[:,1]], axis = 1)
    train_res.columns = ['y_train', 'prob']
    test_res.columns = ['y_test', 'prob']
    
    train_prob_True1 = train_res[train_res.y_train == 1]
    train_prob_True0 = train_res[train_res.y_train == 0]
    
    test_prob_True1 = test_res[test_res.y_test == 1]
    test_prob_True0 = test_res[test_res.y_test == 0]
    
    dict_res_ks = {'Treino': [stats.ks_2samp(train_prob_True1.prob, train_prob_True0.prob).statistic], 
                   'Teste': [stats.ks_2samp(test_prob_True1.prob, test_prob_True0.prob).statistic]}
    
    res_aux_ks = pd.DataFrame(dict_res_ks, index = ['KS'])
    results = pd.concat([results, res_aux_ks], axis = 0)
    
    return results

def results_cv(clf, X_train, y_train, kcv):
    
    classifier = clf.fit(X_train, np.ravel(y_train))
    metrics = ['f1', 'precision', 'recall', 'accuracy', 'roc_auc']
    
    results = pd.DataFrame()
    for m in metrics:
        cv_results = cross_validate(clf, X_train, np.ravel(y_train), scoring = m, cv = kcv, return_train_score = True)
        dict_res = {'' + m + '_Treino': cv_results['train_score'], 
                    '' + m + '_Teste': cv_results['test_score']}
        res_aux = pd.DataFrame(dict_res)
        results = pd.concat([results, res_aux], axis = 1)
        
    results_mean = np.transpose(pd.DataFrame(results.mean(), columns=['media']))
    results = pd.concat([results, results_mean], axis = 0)
    return results


def grid_search(clf, X_train, y_train, params, score, cv):    
    grid = GridSearchCV(clf, params, scoring = score, cv = cv, return_train_score=True)
    grid_fitted = grid.fit(X_train, np.ravel(y_train))
    print ("Best score: %.4f" % grid_fitted.best_score_)
    print ("Best parameters: %s" % grid_fitted.best_params_)
    return grid_fitted, grid_fitted.best_estimator_, grid_fitted.cv_results_

# %%
def report_teste(predictions, alg_name):

    print('Resultados para o classificador {0}:'.format(alg_name))
    print(classification_report(y_teste, predictions), 
    print ("Acurácia para o treino é ", accuracy_score(y_teste,predictions)))
    
def report_treino(predictions, alg_name):

    print('Resultados para o classificador {0}:'.format(alg_name))
    print(classification_report(y_treino, predictions), 
    print ("Acurácia para o treino é ", accuracy_score(y_treino,predictions)))

# %% [markdown]
# #### Dados

# %%
dataset = pd.read_csv('C:\\Users\\Fabiel Fernando\\Desktop\\PROVA\\classificacao_Q4.csv')
dataset.columns
names = dataset.columns
names_index = names[0:100]
names_index
# Out:
# Index(['x0', 'x1', 'x2', 'x3', 'x4', 'x5', 'x6', 'x7', 'x8', 'x9', 'x10',
#        'x11', 'x12', 'x13', 'x14', 'x15', 'x16', 'x17', 'x18', 'x19', 'x20',
#        'x21', 'x22', 'x23', 'x24', 'x25', 'x26', 'x27', 'x28', 'x29', 'x30',
#        'x31', 'x32', 'x33', 'x34', 'x35', 'x36', 'x37', 'x38', 'x39', 'x40',
#        'x41', 'x42', 'x43', 'x44', 'x45', 'x46', 'x47', 'x48', 'x49', 'x50',
#        'x51', 'x52', 'x53', 'x54', 'x55', 'x56', 'x57', 'x58', 'x59', 'x60',
#        'x61', 'x62', 'x63', 'x64', 'x65', 'x66', 'x67', 'x68', 'x69', 'x70',
#        'x71', 'x72', 'x73', 'x74', 'x75', 'x76', 'x77', 'x78', 'x79', 'x80',
#        'x81', 'x82', 'x83', 'x84', 'x85', 'x86', 'x87', 'x88', 'x89', 'x90',
#        'x91', 'x92', 'x93', 'x94', 'x95', 'x96', 'x97', 'x98', 'x99'],
#       dtype='object')

# %%
#Verificando a existência de missings
#dataset.apply(lambda x: x.isnull().sum())

# %%
dataset.head(5)
# Out:
#          x0        x1        x2        x3        x4        x5        x6  \
# 0  1.696199 -0.792598 -0.349427 -0.464560  3.187014  0.035976  1.033274
# 1 -0.236696 -2.202342  0.024023  1.497700 -0.069758 -2.467088  1.126529
# 2 -0.436683  1.563816 -0.895999 -0.580425  0.311060 -0.187369  0.805249
# 3  1.425908  0.400055 -0.305038 -0.930251 -2.214549  1.763379 -0.239868
# 4 -0.186156 -0.975764  0.594660 -1.181980 -1.443414 -0.797651 -1.252608
#
#          x7        x8        x9       x10       x11       x12       x13  \
# 0 -1.504968  0.204693  1.691204 -0.148668 -4.074097 -0.032896 -0.663494
# 1 -0.570557  2.079251 -1.882632 -0.827576  1.005103 -0.137394  1.189628
# 2 -2.399522 -0.578818  1.586981 -1.941955 -0.596377 -0.489321 -1.030148
# 3 -2.058891 -1.006533 -2.156839 -0.817310  3.135035 -1.046031  2.035231
# 4 -0.060452  0.130702 -2.343517  0.892393 -0.533092 -0.760388 -0.702277
#
#         x14       x15       x16       x17       x18       x19       x20  \
# 0 -0.386016 -0.237805 -1.510523 -1.570864 -0.368605  0.812503  0.549905
# 1 -0.851586 -1.288871 -0.963559  1.227582  0.715197  0.520097  0.588903
# 2 -0.485569  0.902347  0.107147 -0.780838  0.402332 -1.450170 -0.583627
# 3  0.307369 -0.831289 -0.263652 -1.479070 -0.675276 -0.222479 -0.441100
# 4  0.259456  3.732211  1.185647  2.046445 -1.378246 -0.733557  4.716702
#
#         x21       x22       x23       x24       x25       x26       x27  \
# 0 -0.730260  0.761423  1.128273 -1.763750  0.579692 -0.293674  0.295500
# 1 -0.590111 -2.210356  1.022461 -1.039452 -0.241972  0.282824  0.001147
# 2 -0.706544 -0.025883 -1.450107  2.118729  1.015845  0.166787 -0.044010
# 0  1.291322 -0.795223  1.292448  0.804562  0.822480 -1.205006 -0.280887
# 1  0.661217 -1.936414 -1.698198 -3.313671 -0.183713 -0.549041  1.280620
# 2 -1.912456 -1.829811 -0.589138  0.473086 -0.237060 -0.106093 -0.690060
# 3 -1.478115 -2.388252 -1.569214 -2.755844 -1.098166  1.450431  1.134263
# 4  1.012526 -0.554645  0.451229  0.484063  2.466720  0.102488 -0.574971
#
#         x77       x78       x79       x80       x81       x82       x83  \
# 0 -1.364098  0.312000 -1.925461  0.498012  0.371394  0.176175  0.547430
# 1  2.177973  0.706155 -1.002186 -0.760492  0.390230  1.652978 -0.281058
# 2 -0.640960 -1.088658 -0.998397 -1.579437 -0.697638 -0.620487 -0.320028
# 3  2.586703 -0.224750 -0.036701  2.264622 -0.035200  0.217302  0.038805
# 4 -2.885352  0.911710 -0.846603  0.850602  2.222440 -1.981894  0.156248
#
#         x84       x85       x86       x87       x88       x89       x90  \
# 0  1.058247  0.503351  1.018997  0.221213 -0.419000 -0.858737 -0.534360
# 1 -2.274763 -1.451749 -0.594344  1.292452  1.066120  0.036062  0.498207
# 2  1.390414  0.449638  0.300941 -0.512526  0.656667  0.265771 -2.630024
# 3 -0.604043 -1.798876 -2.307973  1.441341  2.311820 -0.947016 -0.260665
# 4 -2.788302 -0.067919  1.352606 -1.878879 -0.943184 -0.185896  1.098563
#
#         x91       x92       x93       x94       x95       x96       x97  \
# 0  1.488142 -0.686337  2.084970 -0.685140 -2.049451  2.015426  1.158477
# 1  0.405567  0.509564  1.374071 -0.016943 -0.429280 -0.895016  1.259566
# 2  0.933578 -1.285978  0.503162  0.204829 -0.753835  0.290033  1.721487
# 3 -0.849927  1.402768  0.393653 -1.466818  0.152257 -4.004950  0.676342
# 4 -1.444435 -1.818126  0.446574  0.239328  0.802939 -2.035289 -1.433793
#
#         x98       x99  target
# 0 -0.309441 -1.549833     4.0
# 1 -0.354139  0.806797     5.0
# 2  1.304518  0.478903     3.0
# 3 -1.927319  1.959032     8.0
# 4 -0.218596  0.619317     9.0

# %%
print("Dimensão dos nossos dados:\n", 
     dataset.shape)
#print("Tipo de variáveis:\n",
#     dataset.dtypes)
# Out:
# Dimensão dos nossos dados:
#  (1500, 101)

# %% [markdown]
# #### Pocentagem da variável resposta

# %%
resposta = dataset['target']
count = pd.DataFrame(resposta.value_counts())
percent = pd.DataFrame(resposta.value_counts(normalize = True)*100)
table = pd.concat([count, percent], axis = 1)
table.columns = ['# target', '% target']
table
# Out:
#      # target   % target
# 2.0       153  10.200000
# 8.0       153  10.200000
# 3.0       152  10.133333
# 0.0       150  10.000000
# 4.0       150  10.000000
# 1.0       149   9.933333
# 6.0       149   9.933333
# 9.0       149   9.933333
# 5.0       148   9.866667
# 7.0       147   9.800000

# %%
#Descritiva de algumas variáveis
#dataset.describe()

# %% [markdown]
# #### Treino e Teste

# %%
feature_space = dataset.iloc[:, dataset.columns != 'target']
feature_class = dataset.iloc[:, dataset.columns == 'target']


X_treino, X_teste, y_treino, y_teste = train_test_split(feature_space,
                                                                    feature_class,
                                                                    test_size = 0.30, 
                                                                    random_state = 42)

# %%
# Limpar conjuntos de teste para evitar futuras mensagens de aviso
y_treino = y_treino.values.ravel() 
y_teste = y_teste.values.ravel()

# %% [markdown]
# ## Ajustando Random Forest

# %%
#criterio = "gini"
criterio = "entropy"

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(criterion = criterio,
                                       max_depth=3, #máximo de divisões para todas as árvores na floresta
                                       min_samples_leaf = 5, 
                                       min_samples_split = 10,   
                                       n_estimators=100, 
                                       max_features='auto', #máximo de variáveis que serão usados na divisão de nós
                                       oob_score=True, 
                                       random_state=42, 
                                       n_jobs=-1)
classifier.fit(X_treino, y_treino)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#             max_depth=3, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=5, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#             oob_score=True, random_state=42, verbose=0, warm_start=False)

# %% [markdown]
# #### Precisão do classificador

# %%
pred_test = classifier.predict(X_teste)
pred_train = classifier.predict(X_treino)

# %% [markdown]
# #### Tabela com cálculo de vária métricas conjunto treino

# %%
report_treino(pred_train,'treino')
# Out:
# Resultados para o classificador treino:
# Acurácia para o treino é  0.6361904761904762
#              precision    recall  f1-score   support
#
#         0.0       0.65      0.83      0.73       103
#         1.0       0.56      0.55      0.56        98
#         2.0       0.76      0.35      0.48       111
#         3.0       0.70      0.69      0.69       105
#         4.0       0.58      0.54      0.56       104
#         5.0       0.71      0.57      0.63        97
#         6.0       0.60      0.64      0.62        98
#         7.0       0.61      0.68      0.64       111
#         8.0       0.64      0.68      0.66       106
#         9.0       0.63      0.82      0.71       117
#
# avg / total       0.65      0.64      0.63      1050
#  None

# %% [markdown]
# #### Tabela com cálculo de vária métricas conjunto teste

# %%
report_teste(pred_test,'treino')
# Out:
# Resultados para o classificador treino:
# Acurácia para o treino é  0.5755555555555556
#              precision    recall  f1-score   support
#
#         0.0       0.64      0.94      0.76        47
#         1.0       0.46      0.51      0.49        51
#         2.0       0.55      0.29      0.37        42
#         3.0       0.65      0.70      0.67        47
#         4.0       0.46      0.37      0.41        46
#         5.0       0.76      0.57      0.65        51
#         6.0       0.69      0.43      0.53        51
#         7.0       0.53      0.58      0.55        36
#         8.0       0.66      0.66      0.66        47
#         9.0       0.41      0.75      0.53        32
#
# avg / total       0.59      0.58      0.57       450
#  None

# %% [markdown]
# ## Ajustando o classificador com Grid Search

# %%
# random state para reproducibilidade
fit_rf = RandomForestClassifier(random_state=42)

# %%
np.random.seed(42)
cv_kfold = KFold(10, shuffle = False)

param_grid = {
                "n_estimators" : [9, 18, 27, 36, 45, 54, 63],
                "max_depth" : [1, 5, 10, 15, 20, 25, 30],
                "min_samples_leaf" : [1, 2, 4, 6, 8, 10]
             }

# %%
cv_rf = GridSearchCV(fit_rf,
                     cv = cv_kfold,
                     param_grid = param_grid,
                     scoring = 'accuracy',
                     return_train_score= True,
                     n_jobs = 3)

# %%
gridcv_rf = cv_rf.fit(X_treino, y_treino)

# %%
modelo_randomforest = gridcv_rf.best_estimator_

# %%
gridcv_rf.best_score_
# Out:
# 0.7066666666666667

# %%
pd.DataFrame(gridcv_rf.cv_results_)
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0         0
# 13                1                      2                 63
# 14                1                      4                  9
# 15                1                      4                 18
# 16                1                      4                 27
# 17                1                      4                 36
# 18                1                      4                 45
# 19                1                      4                 54
# 20                1                      4                 63
# 21                1                      6                  9
# 22                1                      6                 18
# 23                1                      6                 27
# 24                1                      6                 36
# 25                1                      6                 45
# 26                1                      6                 54
# 27                1                      6                 63
# 28                1                      8                  9
# 29                1                      8                 18
# ..              ...                    ...                ...
# 264              30                      2                 54
# 265              30                      2                 63
# 266              30                      4                  9
# 267              30                      4                 18
# 268              30                      4                 27
# 269              30                      4                 36
# 270              30                      4                 45
# 271              30                      4                 54
# 272              30                      4                 63
# 273              30                      6                  9
# 274              30                      6                 18
# 275              30                      6                 27
# 276              30                      6                 36
# 277              30                      6                 45
# 278              30                      6                 54
# 279              30                      6                 63
# 280              30                      8                  9
# 281              30                      8                 18
# 282              30                      8                 27
# 283              30                      8                 36
# 284              30                      8                 45
# 285              30                      8                 54
# 286              30                      8                 63
# 287              30                     10                  9
# 288              30                     10                 18
# 289              30                     10                 27
# 290              30                     10                 36
# 291              30                     10                 45
# 292              30                     10                 54
# 293              30                     10                 63
#
#                                                 params  split0_test_score  \
# 0    {'max_depth': 1, 'min_samples_leaf': 1, 'n_est...           0.457143
# 1    {'max_depth': 1, 'min_samples_leaf': 1, 'n_est...           0.447619
# 2    {'max_depth': 1, 'min_samples_leaf': 1, 'n_est...           0.457143
# 3    {'max_depth': 1, 'min_samples_leaf': 1, 'n_est...           0.457143
# 4    {'max_depth': 1, 'min_samples_leaf': 1, 'n_est...           0.428571
# 5    {'max_depth': 1, 'min_samples_leaf': 1, 'n_est...           0.419048
# 6    {'max_depth': 1, 'min_samples_leaf': 1, 'n_est...           0.380952
# 7    {'max_depth': 1, 'min_samples_leaf': 2, 'n_est...           0.457143
# 8    {'max_depth': 1, 'min_samples_leaf': 2, 'n_est...           0.447619
# 9    {'max_depth': 1, 'min_samples_leaf': 2, 'n_est...           0.457143
# 10   {'max_depth': 1, 'min_samples_leaf': 2, 'n_est...           0.457143
# 11   {'max_depth': 1, 'min_samples_leaf': 2, 'n_est...           0.428571
# 12   {'max_depth': 1, 'min_samples_leaf': 2, 'n_est...           0.419048
# 13   {'max_depth': 1, 'min_samples_leaf': 2, 'n_est...           0.380952
# 14   {'max_depth': 1, 'min_samples_leaf': 4, 'n_est...           0.457143
# 15   {'max_depth': 1, 'min_samples_leaf': 4, 'n_est...           0.447619
# 16   {'max_depth': 1, 'min_samples_leaf': 4, 'n_est...           0.457143
# 17   {'max_depth': 1, 'min_samples_leaf': 4, 'n_est...           0.457143
# 18   {'max_depth': 1, 'min_samples_leaf': 4, 'n_est...           0.428571
# 19   {'max_depth': 1, 'min_samples_leaf': 4, 'n_est...           0.419048
# 20   {'max_depth': 1, 'min_samples_leaf': 4, 'n_est...           0.380952
# 21   {'max_depth': 1, 'min_samples_leaf': 6, 'n_est...           0.457143
# 22   {'max_depth': 1, 'min_samples_leaf': 6, 'n_est...           0.447619
# 23   {'max_depth': 1, 'min_samples_leaf': 6, 'n_est...           0.457143
# 24   {'max_depth': 1, 'min_samples_leaf': 6, 'n_est...           0.457143
# 25   {'max_depth': 1, 'min_samples_leaf': 6, 'n_est...           0.428571
# 26   {'max_depth': 1, 'min_samples_leaf': 6, 'n_est...           0.419048
# 27   {'max_depth': 1, 'min_samples_leaf': 6, 'n_est...           0.380952
# 28   {'max_depth': 1, 'min_samples_leaf': 8, 'n_est...           0.457143
# 29   {'max_depth': 1, 'min_samples_leaf': 8, 'n_est...           0.447619
# ..                                                 ...                ...
# 264  {'max_depth': 30, 'min_samples_leaf': 2, 'n_es...           0.800000
# 265  {'max_depth': 30, 'min_samples_leaf': 2, 'n_es...           0.790476
# 266  {'max_depth': 30, 'min_samples_leaf': 4, 'n_es...           0.733333
# 267  {'max_depth': 30, 'min_samples_leaf': 4, 'n_es...           0.752381
# 268  {'max_depth': 30, 'min_samples_leaf': 4, 'n_es...           0.809524
# 269  {'max_depth': 30, 'min_samples_leaf': 4, 'n_es...           0.790476
# 270  {'max_depth': 30, 'min_samples_leaf': 4, 'n_es...           0.800000
# 271  {'max_depth': 30, 'min_samples_leaf': 4, 'n_es...           0.790476
# 272  {'max_depth': 30, 'min_samples_leaf': 4, 'n_es...           0.819048
# 273  {'max_depth': 30, 'min_samples_leaf': 6, 'n_es...           0.723810
# 274  {'max_depth': 30, 'min_samples_leaf': 6, 'n_es...           0.742857
# 275  {'max_depth': 30, 'min_samples_leaf': 6, 'n_es...           0.771429
# 276  {'max_depth': 30, 'min_samples_leaf': 6, 'n_es...           0.771429
# 277  {'max_depth': 30, 'min_samples_leaf': 6, 'n_es...           0.771429
# 278  {'max_depth': 30, 'min_samples_leaf': 6, 'n_es...           0.790476
# 279  {'max_depth': 30, 'min_samples_leaf': 6, 'n_es...           0.771429
# 280  {'max_depth': 30, 'min_samples_leaf': 8, 'n_es...           0.714286
# 281  {'max_depth': 30, 'min_samples_leaf': 8, 'n_es...           0.742857
# 282  {'max_depth': 30, 'min_samples_leaf': 8, 'n_es...           0.742857
# 283  {'max_depth': 30, 'min_samples_leaf': 8, 'n_es...           0.742857
# 284  {'max_depth': 30, 'min_samples_leaf': 8, 'n_es...           0.771429
# 285  {'max_depth': 30, 'min_samples_leaf': 8, 'n_es...           0.752381
# 286  {'max_depth': 30, 'min_samples_leaf': 8, 'n_es...           0.771429
# 287  {'max_depth': 30, 'min_samples_leaf': 10, 'n_e...           0.704762
# 288  {'max_depth': 30, 'min_samples_leaf': 10, 'n_e...           0.752381
# 289  {'max_depth': 30, 'min_samples_leaf': 10, 'n_e...           0.752381
# 290  {'max_depth': 30, 'min_samples_leaf': 10, 'n_e...           0.761905
# 291  {'max_depth': 30, 'min_samples_leaf': 10, 'n_e...           0.771429
# 292  {'max_depth': 30, 'min_samples_leaf': 10, 'n_e...           0.771429
# 293  {'max_depth': 30, 'min_samples_leaf': 10, 'n_e...           0.771429
#
#      split1_test_score  split2_test_score  split3_test_score  \
# 0             0
# 18             0.448677            0.423280          0.430476         0.025950
# 19             0.431746            0.427513          0.424550         0.024726
# 20             0.410582            0.422222          0.412910         0.021462
# 21             0.360847            0.368254          0.386138         0.022723
# 22             0.411640            0.396825          0.422011         0.023836
# 23             0.416931            0.409524          0.421164         0.031309
# 24             0.448677            0.427513          0.420741         0.022031
# 25             0.448677            0.423280          0.430476         0.025950
# 26             0.431746            0.427513          0.424550         0.024726
# 27             0.410582            0.422222          0.412910         0.021462
# 28             0.360847            0.368254          0.386138         0.022723
# 29             0.411640            0.396825          0.422011         0.023836
# ..                  ...                 ...               ...              ...
# 264            0.995767            0.995767          0.995450         0.000826
# 265            0.995767            1.000000          0.996085         0.001710
# 266            0.896296            0.910053          0.906138         0.005376
# 267            0.921693            0.929101          0.931111         0.004974
# 268            0.924868            0.938624          0.938519         0.006339
# 269            0.940741            0.950265          0.946561         0.003612
# 270            0.942857            0.948148          0.947513         0.003965
# 271            0.950265            0.942857          0.950265         0.004514
# 272            0.948148            0.951323          0.951958         0.003516
# 273            0.864550            0.843386          0.850688         0.007768
# 274            0.889947            0.881481          0.879365         0.005031
# 275            0.894180            0.893122          0.890476         0.004762
# 276            0.900529            0.894180          0.898519         0.002479
# 277            0.902646            0.893122          0.899048         0.003319
# 278            0.907937            0.892063          0.902540         0.005487
# 279            0.911111            0.889947          0.904444         0.006297
# 280            0.816931            0.811640          0.807513         0.007996
# 281            0.843386            0.845503          0.845079         0.006612
# 282            0.859259            0.848677          0.852910         0.006260
# 283            0.864550            0.851852          0.859365         0.004767
# 284            0.866667            0.856085          0.862857         0.005123
# 285            0.874074            0.858201          0.863915         0.006138
# 286            0.877249            0.858201          0.865079         0.006911
# 287            0.797884            0.792593          0.785397         0.008316
# 288            0.829630            0.809524          0.818095         0.009291
# 289            0.830688            0.825397          0.823386         0.007215
# 290            0.838095            0.823280          0.831534         0.007873
# 291            0.831746            0.822222          0.830265         0.008468
# 292            0.837037            0.822222          0.833333         0.007866
# 293            0.838095            0.827513          0.835238         0.005949
#
# [294 rows x 33 columns]

# %% [markdown]
# #### Variáveis Importantes

# %%
def variable_importance(fit):
    importances = fit.feature_importances_
    indices = np.argsort(importances)[::-1]
    return {'importance': importances,
            'index': indices}

# %%
var_imp_rf = variable_importance(modelo_randomforest)
importances_rf = var_imp_rf['importance']
indices_rf = var_imp_rf['index']

# %%
def print_var_importance(importance, indices, name_index):
    print("Ranking das variáveis mais importantes:")
    for f in range(0, 5):
        i = f
        print("{0}. A variável '{1}' tem uma diminuição média na impureza de {2:.5f}"
              .format(f + 1,
                      names_index[indices[i]],
                      importance[indices[f]]))

# %%
print_var_importance(importances_rf, indices_rf, names_index)
# Out:
# Ranking das variáveis mais importantes:
# 1. A variável 'x57' tem uma diminuição média na impureza de 0.03223
# 2. A variável 'x69' tem uma diminuição média na impureza de 0.03221
# 3. A variável 'x41' tem uma diminuição média na impureza de 0.03054
# 4. A variável 'x79' tem uma diminuição média na impureza de 0.03018
# 5. A variável 'x35' tem uma diminuição média na impureza de 0.02897

# %% [markdown]
# ## Validação Cruzada

# %% [markdown]
# ### K - fold

# %%
X = dataset.iloc[:, 0:100].values
y = dataset['target'].astype('category')

# %%
from sklearn import model_selection
kfold = model_selection.KFold(n_splits=10, random_state=42)
model = RandomForestClassifier()
scoring = 'accuracy'
results = model_selection.cross_val_score(model, X, y, cv=kfold, scoring=scoring)
results.mean(), results.std()
# Out:
# (0.6639999999999999, 0.04753478258660237)

# %%
results
# Out:
# array([0.66666667, 0.69333333, 0.66      , 0.72666667, 0.63333333,
#        0.68666667, 0.62      , 0.65333333, 0.73333333, 0.56666667])

# %% [markdown]
# ### LOOCV

# %%
model = RandomForestClassifier()
accuracies = cross_val_score(model, X=X, y=y, cv=LeaveOneOut())
accuracies.mean()
# Out:
# 0.672

# %% [markdown]
# ### Repeat CV

# %%
from sklearn.model_selection import RepeatedKFold
cv_repeat = RepeatedKFold(n_splits=6, n_repeats=3, random_state=42)
model = RandomForestClassifier()
accuracies = cross_val_score(model, X=X, y=y, cv=cv_repeat)
accuracies.mean()
# Out:
# 0.6542222222222221

# %% [markdown]
# ### Separando as k primeiras observações para treino e o restante para teste

# %%
X_treino = dataset.iloc[0:499, 0:99].values
y_treino = dataset.iloc[0:499, 100].values


X_teste = dataset.iloc[500:1500, 0:99].values
y_teste = dataset.iloc[500:1500, 100].values

# %%
#criterio = 'gini'
criterio = 'entropy'

# %%
clf = RandomForestClassifier(criterion = criterio,
                                       max_depth=3,
                                       min_samples_leaf = 1, 
                                       min_samples_split = 10,   
                                       n_estimators=100, 
                                       max_features='auto', 
                                       oob_score=True, 
                                       random_state=42, 
                                       n_jobs=-1)
clf.fit(X_treino, y_treino)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#             max_depth=3, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#             oob_score=True, random_state=42, verbose=0, warm_start=False)

# %% [markdown]
# #### Precisão do classificador no Random Forest

# %%
pred_teste = clf.predict(X_teste)
pred_treino = clf.predict(X_treino)

# %% [markdown]
# #### Métricas Treino

# %%
 report_treino(pred_treino, 'Random Forest')
# Out:
# Resultados para o classificador Random Forest:
# Acurácia para o treino é  0.687374749498998
#              precision    recall  f1-score   support
#
#         0.0       0.59      0.85      0.70        55
#         1.0       0.65      0.77      0.70        48
#         2.0       0.89      0.38      0.53        45
#         3.0       0.68      0.81      0.74        58
#         4.0       0.81      0.44      0.57        48
#         5.0       0.83      0.54      0.66        46
#         6.0       0.60      0.79      0.68        47
#         7.0       0.74      0.67      0.70        51
#         8.0       0.90      0.63      0.74        41
#         9.0       0.64      0.87      0.74        60
#
# avg / total       0.72      0.69      0.68       499
#  None

# %% [markdown]
# #### Métricas Teste

# %%
report_teste(pred_teste, 'Random Forest')
# Out:
# Resultados para o classificador Random Forest:
# Acurácia para o treino é  0.57
#              precision    recall  f1-score   support
#
#         0.0       0.55      0.80      0.65        95
#         1.0       0.56      0.58      0.57       101
#         2.0       0.65      0.29      0.40       108
#         3.0       0.56      0.76      0.64        94
#         4.0       0.63      0.24      0.34       102
#         5.0       0.68      0.42      0.52       102
#         6.0       0.55      0.75      0.64       102
#         7.0       0.56      0.52      0.54        96
#         8.0       0.73      0.55      0.63       111
#         9.0       0.46      0.88      0.60        89
#
# avg / total       0.60      0.57      0.55      1000
#  None
